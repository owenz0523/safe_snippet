# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("../images/croppedimage.png")
hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.imshow(img)
plt.show()

#bottom_half_image = img[int(img.shape[0]/2):, :]
#plt.imshow(bottom_half_image)
#plt.show()

lower_blue = np.array([85, 105, 85])
upper_blue = np.array([135, 165, 185])

mask = cv2.inRange(hsv_img, lower_blue, upper_blue)

print(np.any(mask > 0))
# Out:
# True
